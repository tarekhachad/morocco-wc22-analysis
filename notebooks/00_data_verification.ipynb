# %% [markdown]
#  ### Confirm WC2022 is available

# %%
from statsbombpy import sb

compets = sb.competitions()
wc2022 = compets[
    (compets['competition_name'] == 'FIFA World Cup') &
    (compets['season_name'] == '2022')
]
print(wc2022[['competition_id', 'season_id', 'competition_name', 'season_name']])
# Out:
# /Users/tarekhachad/dev/morocco-wc22-analysis/venv/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     competition_id  season_id competition_name season_name
# 29              43        106   FIFA World Cup        2022

# %% [markdown]
# ### Confirm Morocco matches are available

# %%
matches = sb.matches(competition_id=43, season_id=106)

morocco = matches[
    (matches['home_team'] == 'Morocco') |
    (matches['away_team'] == 'Morocco')
]

print(morocco[['match_id', 'home_team', 'away_team', 'home_score', 'away_score']])
# Out:
#     match_id home_team away_team  home_score  away_score
# 8    3869486   Morocco  Portugal           1           0
# 18   3869684   Croatia   Morocco           2           1
# 21   3869552    France   Morocco           2           0
# 23   3869220   Morocco     Spain           0           0
# 32   3857283   Belgium   Morocco           0           2
# 51   3857277   Morocco   Croatia           0           0
# 52   3857276    Canada   Morocco           1           2
# /Users/tarekhachad/dev/morocco-wc22-analysis/venv/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %% [markdown]
# ### Confirm event data loads for one match

# %%
match_id = morocco['match_id'].iloc[0]
events = sb.events(match_id=match_id)
print(events.shape)
print(events['type'].value_counts())
# Out:
# /Users/tarekhachad/dev/morocco-wc22-analysis/venv/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# (3381, 92)
# Pass                 980
# Ball Receipt*        881
# Carry                805
# Pressure             242
# Ball Recovery         95
# Duel                  54
# Miscontrol            39
# Clearance             38
# Block                 33
# Dribble               28
# Foul Committed        27
# Goal Keeper           27
# Foul Won              26
# Shot                  21
# Interception          19
# Dribbled Past         14
# Dispossessed          12
# Substitution          10
# Tactical Shift         7
# Injury Stoppage        4
# Half Start             4
# Half End               4
# Player On              2
# Player Off             2
# Starting XI            2
# Shield                 2
# Referee Ball-Drop      2
# Error                  1
# Name: type, dtype: int64

# %% [markdown]
# ### Confirm 360 data loads for the same match

# %%
frames = sb.frames(match_id=match_id)
print(frames.shape)
# Out:
# /Users/tarekhachad/dev/morocco-wc22-analysis/venv/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# (51761, 7)
